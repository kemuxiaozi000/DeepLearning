# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.0.0
# sys.version_info(major=3, minor=6, micro=3, releaselevel='final', serial=0)
# matplotlib 3.1.2
# numpy 1.17.4
# pandas 0.25.3
# sklearn 0.21.3
# tensorflow 2.0.0
# tensorflow_core.keras 2.2.4-tf

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all, y_train_all), (x_test, y_test) = fashion_mnist.load_data()
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]

print(x_valid.shape, y_valid.shape)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (5000, 28, 28) (5000,)
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %%
def show_single_image(img_arr):
    plt.imshow(img_arr, cmap="binary")
    plt.show()

show_single_image(x_train[0])

# %%
def show_imgs(n_rows, n_cols, x_data, y_data, class_names):
    assert len(x_data) == len(y_data)
    assert n_rows * n_cols < len(x_data)
    plt.figure(figsize = (n_cols * 1.4, n_rows * 1.6))
    for row in range(n_rows):
        for col in range(n_cols):
            index = n_cols * row + col 
            plt.subplot(n_rows, n_cols, index+1)
            plt.imshow(x_data[index], cmap="binary",
                       interpolation = 'nearest')
            plt.axis('off')
            plt.title(class_names[y_data[index]])
    plt.show()

class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress',
               'Coat', 'Sandal', 'Shirt', 'Sneaker',
               'Bag', 'Ankle boot']
show_imgs(3, 5, x_train, y_train, class_names)

# %%
# tf.keras.models.Sequential()

"""
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))
"""

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# relu: y = max(0, x)
# softmax: 将向量变成概率分布. x = [x1, x2, x3], 
#          y = [e^x1/sum, e^x2/sum, e^x3/sum], sum = e^x1 + e^x2 + e^x3

# reason for sparse: y->index. y->one_hot->[] 
# 类别，交叉熵损失函数
# 构建图
model.compile(loss="sparse_categorical_crossentropy",
#               optimizer = "sgd",
              optimizer = "adam",
              metrics = ["accuracy"])

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.core.Flatten at 0x181404d7898>,
#  <tensorflow.python.keras.layers.core.Dense at 0x181404d79e8>,
#  <tensorflow.python.keras.layers.core.Dense at 0x181404d7cf8>,
#  <tensorflow.python.keras.layers.core.Dense at 0x181404e7048>]

# %%
# 打出模型架构
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               235500
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
# [None, 784] * W + b -> [None, 300] W.shape [784, 300], b = [300]

# %%
history = model.fit(x_train, y_train, epochs=50,
                    validation_data=(x_valid, y_valid))
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/50
# 55000/55000 [==============================] - 6s 104us/sample - loss: 0.3490 - accuracy: 0.8749 - val_loss: 0.3572 - val_accuracy: 0.8760
# Epoch 2/50
# 55000/55000 [==============================] - 6s 110us/sample - loss: 0.3409 - accuracy: 0.8761 - val_loss: 0.3661 - val_accuracy: 0.8748
# Epoch 3/50
# 55000/55000 [==============================] - 6s 101us/sample - loss: 0.3415 - accuracy: 0.8787 - val_loss: 0.3794 - val_accuracy: 0.8690
# Epoch 4/50
# 55000/55000 [==============================] - 6s 100us/sample - loss: 0.3333 - accuracy: 0.8814 - val_loss: 0.3378 - val_accuracy: 0.8834
# Epoch 5/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.3238 - accuracy: 0.8844 - val_loss: 0.3904 - val_accuracy: 0.8650
# Epoch 6/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.3223 - accuracy: 0.8846 - val_loss: 0.3837 - val_accuracy: 0.8790
# Epoch 7/50
# 55000/55000 [==============================] - 6s 104us/sample - loss: 0.3141 - accuracy: 0.8870 - val_loss: 0.3883 - val_accuracy: 0.8714
# Epoch 8/50
# 55000/55000 [==============================] - 6s 105us/sample - loss: 0.3102 - accuracy: 0.8876 - val_loss: 0.3664 - val_accuracy: 0.8802
# Epoch 9/50
# 55000/55000 [==============================] - 6s 105us/sample - loss: 0.3121 - accuracy: 0.8879 - val_loss: 0.3887 - val_accuracy: 0.8774
# Epoch 10/50
# 55000/55000 [==============================] - 6s 107us/sample - loss: 0.3071 - accuracy: 0.8903 - val_loss: 0.3646 - val_accuracy: 0.8826
# Epoch 11/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.3096 - accuracy: 0.8894 - val_loss: 0.4222 - val_accuracy: 0.8752
# Epoch 12/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.3059 - accuracy: 0.8914 - val_loss: 0.4214 - val_accuracy: 0.8794
# Epoch 13/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.2982 - accuracy: 0.8919 - val_loss: 0.4056 - val_accuracy: 0.8812
# Epoch 14/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.2887 - accuracy: 0.8940 - val_loss: 0.4857 - val_accuracy: 0.8764
# Epoch 15/50
# 55000/55000 [==============================] - 6s 104us/sample - loss: 0.2918 - accuracy: 0.8945 - val_loss: 0.3967 - val_accuracy: 0.8772
# Epoch 16/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.2872 - accuracy: 0.8957 - val_loss: 0.4294 - val_accuracy: 0.8708
# Epoch 17/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.2865 - accuracy: 0.8970 - val_loss: 0.4267 - val_accuracy: 0.8818
# Epoch 18/50
# 55000/55000 [==============================] - 6s 104us/sample - loss: 0.2898 - accuracy: 0.8981 - val_loss: 0.4042 - val_accuracy: 0.8750
# Epoch 19/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.2844 - accuracy: 0.8992 - val_loss: 0.5191 - val_accuracy: 0.8790
# Epoch 20/50
# 55000/55000 [==============================] - 6s 103us/sample - loss: 0.2773 - accuracy: 0.9007 - val_loss: 0.4482 - val_accuracy: 0.8760
# Epoch 21/50
# 55000/55000 [==============================] - 5s 100us/sample - loss: 0.2823 - accuracy: 0.8986 - val_loss: 0.4432 - val_accuracy: 0.8800
# Epoch 22/50
# 55000/55000 [==============================] - 6s 100us/sample - loss: 0.2813 - accuracy: 0.8992 - val_loss: 0.4931 - val_accuracy: 0.8766
# Epoch 23/50
# 55000/55000 [==============================] - 6s 102us/sample - loss: 0.2725 - accuracy: 0.9014 - val_loss: 0.5201 - val_accuracy: 0.8738
# Epoch 24/50
# 55000/55000 [==============================] - 5s 96us/sample - loss: 0.2813 - accuracy: 0.9000 - val_loss: 0.5097 - val_accuracy: 0.8738
# Epoch 25/50
# 55000/55000 [==============================] - 6s 102us/sample - loss: 0.2687 - accuracy: 0.9028 - val_loss: 0.4495 - val_accuracy: 0.8784
# Epoch 26/50
# 55000/55000 [==============================] - 6s 108us/sample - loss: 0.2684 - accuracy: 0.9034 - val_loss: 0.4306 - val_accuracy: 0.8806
# Epoch 27/50
# 55000/55000 [==============================] - 7s 121us/sample - loss: 0.2712 - accuracy: 0.9053 - val_loss: 0.4839 - val_accuracy: 0.8642
# Epoch 28/50
# 55000/55000 [==============================] - 6s 104us/sample - loss: 0.2735 - accuracy: 0.9031 - val_loss: 0.6028 - val_accuracy: 0.8610
# Epoch 29/50
# 55000/55000 [==============================] - 6s 105us/sample - loss: 0.2790 - accuracy: 0.9025 - val_loss: 0.4571 - val_accuracy: 0.8758
# Epoch 30/50
# 55000/55000 [==============================] - 6s 105us/sample - loss: 0.2619 - accuracy: 0.9059 - val_loss: 0.5053 - val_accuracy: 0.8774
# Epoch 31/50
# 55000/55000 [==============================] - 6s 105us/sample - loss: 0.2678 - accuracy: 0.9047 - val_loss: 0.4889 - val_accuracy: 0.8694
# Epoch 32/50
# 55000/55000 [==============================] - 6s 107us/sample - loss: 0.2695 - accuracy: 0.9058 - val_loss: 0.4899 - val_accuracy: 0.8828
# Epoch 33/50
# 55000/55000 [==============================] - 6s 107us/sample - loss: 0.2524 - accuracy: 0.9085 - val_loss: 0.4787 - val_accuracy: 0.8748
# Epoch 34/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2662 - accuracy: 0.9056 - val_loss: 0.5302 - val_accuracy: 0.8800
# Epoch 35/50
# 55000/55000 [==============================] - 6s 107us/sample - loss: 0.2555 - accuracy: 0.9083 - val_loss: 0.5052 - val_accuracy: 0.8772
# Epoch 36/50
# 55000/55000 [==============================] - 6s 109us/sample - loss: 0.2587 - accuracy: 0.9089 - val_loss: 0.5009 - val_accuracy: 0.8772
# Epoch 37/50
# 55000/55000 [==============================] - 6s 108us/sample - loss: 0.2660 - accuracy: 0.9073 - val_loss: 0.5765 - val_accuracy: 0.8730
# Epoch 38/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2558 - accuracy: 0.9093 - val_loss: 0.5856 - val_accuracy: 0.8736
# Epoch 39/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2621 - accuracy: 0.9090 - val_loss: 0.5753 - val_accuracy: 0.8706
# Epoch 40/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2524 - accuracy: 0.9117 - val_loss: 0.6504 - val_accuracy: 0.8682
# Epoch 41/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2556 - accuracy: 0.9084 - val_loss: 0.5193 - val_accuracy: 0.8774
# Epoch 42/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2503 - accuracy: 0.9114 - val_loss: 0.4617 - val_accuracy: 0.8856
# Epoch 43/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2454 - accuracy: 0.9121 - val_loss: 0.6117 - val_accuracy: 0.8786
# Epoch 44/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2540 - accuracy: 0.9112 - val_loss: 0.5774 - val_accuracy: 0.8846
# Epoch 45/50
# 55000/55000 [==============================] - 6s 108us/sample - loss: 0.2468 - accuracy: 0.9110 - val_loss: 0.6625 - val_accuracy: 0.8740
# Epoch 46/50
# 55000/55000 [==============================] - 6s 108us/sample - loss: 0.2406 - accuracy: 0.9144 - val_loss: 0.7735 - val_accuracy: 0.8754
# Epoch 47/50
# 55000/55000 [==============================] - 6s 106us/sample - loss: 0.2583 - accuracy: 0.9118 - val_loss: 0.6989 - val_accuracy: 0.8696
# Epoch 48/50
# 55000/55000 [==============================] - 6s 109us/sample - loss: 0.2410 - accuracy: 0.9155 - val_loss: 0.6041 - val_accuracy: 0.8806
# Epoch 49/50
# 55000/55000 [==============================] - 6s 108us/sample - loss: 0.2439 - accuracy: 0.9135 - val_loss: 0.7267 - val_accuracy: 0.8768
# Epoch 50/50
# 55000/55000 [==============================] - 6s 109us/sample - loss: 0.2393 - accuracy: 0.9149 - val_loss: 0.6307 - val_accuracy: 0.8764

# %%
type(history)
# Out:
# tensorflow.python.keras.callbacks.History

# %%
history.history
# Out:
# {'accuracy': [0.87487274,
#   0.87612724,
#   0.8787091,
#   0.88143635,
#   0.88438183,
#   0.8846,
#   0.88698184,
#   0.88763636,
#   0.8879091,
#   0.8903091,
#   0.88943636,
#   0.8913818,
#   0.8918545,
#   0.89403635,
#   0.89454544,
#   0.8957091,
#   0.89698184,
#   0.8980909,
#   0.89916366,
#   0.90074545,
#   0.89861816,
#   0.8992182,
#   0.9013636,
#   0.9,
#   0.9028,
#   0.9034,
#   0.90534544,
#   0.90312725,
#   0.9025091,
#   0.9059273,
#   0.9047273,
#   0.9057818,
#   0.9085091,
#   0.9056182,
#   0.90825456,
#   0.90885454,
#   0.9073091,
#   0.90934545,
#   0.90903634,
#   0.9117091,
#   0.90843636,
#   0.91136366,
#   0.9121091,
#   0.91121817,
#   0.911,
#   0.9143818,
#   0.9118182,
#   0.91547275,
#   0.9135091,
#   0.9148727],
#  'loss': [0.3489580344351855,
#   0.3409384693297473,
#   0.34146104525436055,
#   0.3332845306223089,
#   0.32379916869510306,
#   0.3222861852645874,
#   0.314136542450298,
#   0.3101921830177307,
#   0.3121004810138182,
#   0.3071045336593281,
#   0.3096033905278553,
#   0.3058767631075599,
#   0.2981807380762967,
#   0.28869185712608425,
#   0.29180348064465955,
#   0.2872292467399077,
#   0.28653133449012586,
#   0.28981115353757686,
#   0.2843904785497622,
#   0.2773383589099754,
#   0.2823050509777936,
#   0.28134147504893214,
#   0.2725295321139422,
#   0.2813215190551498,
#   0.26865590914162724,
#   0.26837985238161954,
#   0.2712416505466808,
#   0.2734564168583263,
#   0.2789949651371349,
#   0.2619161010319536,
#   0.2677648380561308,
#   0.26953092335245826,
#   0.25244837228005584,
#   0.2662441363508051,
#   0.25551641023321586,
#   0.2586650798775933,
#   0.2659570992794904,
#   0.255843075733835,
#   0.26211927812099456,
#   0.2524201451171528,
#   0.2555990316504782,
#   0.2502641027504748,
#   0.24544846246621826,
#   0.25399983255023306,
#   0.2467829686587507,
#   0.2405504934462634,
#   0.25829042173515665,
#   0.24103184489553625,
#   0.24388499436161734,
#   0.239277805352211],
#  'val_accuracy': [0.876,
#   0.8748,
#   0.869,
#   0.8834,
#   0.865,
#   0.879,
#   0.8714,
#   0.8802,
#   0.8774,
#   0.8826,
#   0.8752,
#   0.8794,
#   0.8812,
#   0.8764,
#   0.8772,
#   0.8708,
#   0.8818,
#   0.875,
#   0.879,
#   0.876,
#   0.88,
#   0.8766,
#   0.8738,
#   0.8738,
#   0.8784,
#   0.8806,
#   0.8642,
#   0.861,
#   0.8758,
#   0.8774,
#   0.8694,
#   0.8828,
#   0.8748,
#   0.88,
#   0.8772,
#   0.8772,
#   0.873,
#   0.8736,
#   0.8706,
#   0.8682,
#   0.8774,
#   0.8856,
#   0.8786,
#   0.8846,
#   0.874,
#   0.8754,
#   0.8696,
#   0.8806,
#   0.8768,
#   0.8764],
#  'val_loss': [0.3571756072878838,
#   0.3661456011593342,
#   0.379440189409256,
#   0.3377606456041336,
#   0.3904215751469135,
#   0.3837162556409836,
#   0.3883195898771286,
#   0.36640388385653494,
#   0.3886634924709797,
#   0.36460064691901206,
#   0.4222357511162758,
#   0.4213907423555851,
#   0.40557316389083864,
#   0.48573638768196103,
#   0.3966563914179802,
#   0.42944686492681505,
#   0.4267336945295334,
#   0.4042481686711311,
#   0.5191105117440223,
#   0.44816114830970766,
#   0.4431684164851904,
#   0.49308443737626073,
#   0.5201328725278378,
#   0.5097057156801224,
#   0.4494751419901848,
#   0.43058044822216035,
#   0.4839454822063446,
#   0.6028066071391106,
#   0.45713803865909575,
#   0.5053329611063003,
#   0.48892495856285095,
#   0.48990171518921855,
#   0.47869860200285913,
#   0.5302349370718002,
#   0.5051606571793557,
#   0.5009286255598068,
#   0.57652937104702,
#   0.5856127470135689,
#   0.5753395592927932,
#   0.6504102153718472,
#   0.5192874588251114,
#   0.4617464161157608,
#   0.6117448582470417,
#   0.5774132684469223,
#   0.6624834886789321,
#   0.7734968090057373,
#   0.6989073730707168,
#   0.6040715760886669,
#   0.7267499460935593,
#   0.630651324826479]}

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curves(history)
